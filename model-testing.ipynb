# %%
import ultralytics
import cv2
print("Ultralytics and OpenCV are working!")
# Out:
# Ultralytics and OpenCV are working!

# %%
from ultralytics import YOLO
import cv2

# Load your trained model
model = YOLO(r'D:\MY WORK\Project\medical-things-detection\best.pt')

# Open video file
cap = cv2.VideoCapture(r'D:\MY WORK\Project\medical-things-detection\medical-things-test-video\m1.mp4')

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # or 'XVID' for .avi

# Create VideoWriter object
out = cv2.VideoWriter('output1.mp4', fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Inference
    results = model(frame)

    # Draw results on frame
    annotated_frame = results[0].plot()

    # Show frame
    cv2.imshow('YOLO Detection', annotated_frame)

    # Save frame to output video
    out.write(annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 (no detections), 214.0ms
# Speed: 4.2ms preprocess, 214.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 209.4ms
# Speed: 2.2ms preprocess, 209.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 mask, 204.4ms
# Speed: 3.8ms preprocess, 204.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 222.1ms
# Speed: 1.8ms preprocess, 222.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 225.3ms
# Speed: 3.4ms preprocess, 225.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 mask, 209.3ms
# Speed: 1.7ms preprocess, 209.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Coverall, 191.6ms
# Speed: 1.7ms preprocess, 191.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Coverall, 232.8ms
# ...
